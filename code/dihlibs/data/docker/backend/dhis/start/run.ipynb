# %%
import dihlibs.functions as fn
import requests as rq,json


# fn.cmd_wait('pwd')
url='http://admin:Ingia.123@Hatari223@localhost/api/users/M5zQapPyTZI'
rs=rq.get(url).json()
fn.to_file('before.json',)

# %%
rs.json()
# Out:
# {'href': 'http://localhost/api/users/M5zQapPyTZI',
#  'code': 'admin',
#  'name': 'admin admin',
#  'created': '2024-02-17T16:49:37.140',
#  'lastUpdated': '2024-02-18T09:44:58.691',
#  'translations': [],
#  'externalAccess': False,
#  'createdBy': {'id': 'M5zQapPyTZI',
#   'code': 'admin',
#   'name': 'admin admin',
#   'displayName': 'admin admin',
#   'username': 'admin'},
#  'userGroupAccesses': [],
#  'userAccesses': [],
#  'access': {'manage': True,
#   'externalize': True,
#   'write': True,
#   'read': True,
#   'update': True,
#   'delete': True},
#  'favorites': [],
#  'sharing': {'external': False, 'users': {}, 'userGroups': {}},
#  'username': 'admin',
#  'externalAuth': False,
#  'passwordLastUpdated': '2024-02-17T16:49:41.227',
#  'cogsDimensionConstraints': [],
#  'catDimensionConstraints': [],
#  'lastLogin': '2024-02-18T09:44:58.691',
#  'selfRegistered': False,
#  'invitation': False,
#  'disabled': False,
#  'surname': 'admin',
#  'firstName': 'admin',
# ...
